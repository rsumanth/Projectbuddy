# %%
#BY importing the packages from requirements.py or from anaconda packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#By importing the seaborn package
import seaborn as sns

# %%
import seaborn

# %%
# importing csv file
assign = pd.read_csv('Data_Visualization_Assignmnet.csv')

# %%
assign
# Out:
#               DATE DESCRIPTION  UNIT          PLACE
# 0    01 April 2022        Beef   1.0    Kolenchery
# 1    01 April 2022        Fish   1.0    Kolenchery
# 2    03 April 2022        Beef   2.0  Tripunithura
# 3    05 April 2022      Prawns   1.0     Bangalore
# 4    06 April 2022       Dates   1.0      Mangalore
# ..             ...         ...   ...            ...
# 108   15 July 2022        Beef   1.0            NaN
# 109   15 July 2022      Prawns   1.0            NaN
# 110   15 July 2022       Lemon   1.0            NaN
# 111            NaN         NaN   NaN            NaN
# 112            NaN         NaN   NaN            NaN
#
# [113 rows x 4 columns]

# %%
#first five lines of code
print(assign.head())
# Out:
#             DATE DESCRIPTION  UNIT          PLACE
# 0  01 April 2022        Beef   1.0    Kolenchery
# 1  01 April 2022        Fish   1.0    Kolenchery
# 2  03 April 2022        Beef   2.0  Tripunithura
# 3  05 April 2022      Prawns   1.0     Bangalore
# 4  06 April 2022       Dates   1.0      Mangalore

# %%
#To view all the available datasets in the Seaborn library by using get_dataset_names() function
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Set aesthetic parameters with set( ) method by set() method
sns.set()

# %%
#seaborn.palplot() which deals with color palettes
current_palette1 = sns.color_palette()
sns.palplot(current_palette1)
plt.show()

# %%
#by applying green colour to pallete
current_palette2 = sns.color_palette()
sns.palplot( sns.color_palette('Greens'))
plt.show()

# %%
# seaborn.palplot()-which deals with color palettes
current_palette3 = sns.color_palette()
sns.palplot( sns.color_palette('BrBG', 7))
plt.show()

# %%
#set the default color palette of a Seaborn plot using set_palette()function
def sinplot(flip=1):
    x = np.linspace(0, 15, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
        sns.set_style("white")
        sns.set_palette("husl")
        sinplot()
        plt.show()

# %%
#distplot() function provides a quick look at univariate distribution
sns.distplot(assign['UNIT'])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# the distplot() function to plot a histogram 
sns.distplot(assign['UNIT'], kde=False)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# the hist parameter to false in distplot() function will yield the kernel density estimation plot
sns.distplot(assign['UNIT'], hist=False)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#Jointplot() creates a multi-panel figure that projects the bivariate relationship between two variables
sns.jointplot(x="DESCRIPTION", y="PLACE", data=assign)
plt.show()

# %%
#Jointplot() creates a multi-panel figure that projects the bivariate relationship between two variables
sns.jointplot(x="DATE", y="UNIT", data=assign)
plt.show()

# %%
#Jointplot() creates a multi-panel figure that projects the bivariate relationship between two variables
sns.jointplot(x="PLACE", y="UNIT", data=assign)
plt.show()

# %%
#A scatter plot can be used to demonstrate relationship between two variables x and y.
sns.scatterplot(x="PLACE", y="DESCRIPTION", data=assign)
plt.show()

# %%
#A scatter plot can be used to demonstrate relationship between two variables x and y.
sns.scatterplot(x="UNIT", y="DATE", data=assign)
plt.show()

# %%
#To plot multiple pairwise bivariate distributions, we can use pairplot() function.
sns.set_style("ticks")
sns.pairplot(assign)

# %%
#A stripplot() is used to draw a scatterplot where one variable is categorical.
sns.stripplot(x="PLACE", y="UNIT", data=assign)
plt.show()

# %%
#A stripplot() is used to draw a scatterplot where one variable is categorical.
sns.stripplot(x="PLACE", y="DESCRIPTION", data=assign, jitter=True)
plt.show()

# %%
#swarmplot() can be used to draw categorical scatterplot with non-overlapping points
sns.swarmplot(x="PLACE", y="DESCRIPTION", data=assign)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#We can draw a box plot to show distributions with respect to categories by using boxplot function
sns.boxplot(x=assign["UNIT"])
plt.show()

# %%
#We can draw a vertical boxplot grouped by a categorical variable as follows:
sns.boxplot(x="UNIT", y="DATE", data=assign)
plt.show()

# %%
#Violin Plots are combinations of the box plot with the kernel density estimates
sns.violinplot(x=assign["UNIT"])
plt.show()

# %%
#We can draw a vertical violinplot grouped by a categorical variable as follows:-
sns.violinplot(x="UNIT", y="DATE", data=assign)
plt.show()

# %%
#A barplot show point estimates and confidence intervals as rectangular bars.
sns.barplot(x="DATE", y="UNIT", data=assign)
plt.show()

# %%
#We can draw a set of vertical bar plot grouped by a categorical variable as follows:-
sns.barplot(x="UNIT", y="DATE", data=assign)
plt.show()

# %%
#function regplot() plot data and a linear regression model fit
sns.regplot(x="UNIT", y="UNIT" ,data=assign)
plt.show()

# %%
#function lmplot() plot data and regression model fits across a FacetGrid
sns.lmplot(x="UNIT", y="UNIT", data=assign)
plt.show()

# %%
#function residplot() plot the residuals of a linear regression.
sns.residplot(x="UNIT", y="UNIT", data=assign)
plt.show()

# %%
#Seaborn heatmap() function plot rectangular data as a color-encoded matrix.
uniform_data = np.random.rand(10, 12)
sns.heatmap(uniform_data)
plt.show()

# %%
#Seaborn Facetgrid() function enable us to draw multi-plot grid for plotting conditional relationships.
sns.FacetGrid(assign, col="PLACE", row="DESCRIPTION")
plt.show()

# %%
#Seaborn Facetgrid() function enable us to draw multi-plot grid for plotting conditional relationships.
g = sns.FacetGrid(assign, col="PLACE", row="DESCRIPTION")
g = g.map(plt.hist, "DATE")
plt.show()

# %%
#Seaborn PairGrid() function draws subplot grid for plotting pairwise relationships in a dataset
g = sns.PairGrid(assign)
g = g.map(plt.scatter)
plt.show()

# %%
##Seaborn PairGrid() function draws subplot grid for plotting pairwise relationships in a dataset
g = sns.PairGrid(assign)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
#Seaborn JointGrid() function help us to set up the grid of subplots.
g = sns.JointGrid(x="DESCRIPTION", y="PLACE", data=assign)

# %%
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde

sns.pairplot(assign.drop('DESCRIPTION', axis=1), hue='PLACE', size=3)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Another multivariate visualization technique pandas has is parallel_coordinates
# Parallel coordinates plots each feature on a separate column & then draws lines
# connecting the features for each data sample

from pandas.plotting import parallel_coordinates
parallel_coordinates(assign.drop("UNIT", axis=1), "PLACE")
# Out:
# <AxesSubplot:>

# %%
sns.factorplot('DATE', data=assign, hue='PLACE', kind='count' )
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
